# %%
import pandas as pd

# %%
dfi=pd.read_csv('c:/Users/Tarun/Desktop/Hackathon Data/api_data_aadhar_enrolment/api_data_aadhar_enrolment_0_500000.csv')
dfii=pd.read_csv('c:/Users/Tarun/Desktop/Hackathon Data/api_data_aadhar_enrolment/api_data_aadhar_enrolment_500000_1000000.csv')
dfiii=pd.read_csv('c:/Users/Tarun/Desktop/Hackathon Data/api_data_aadhar_enrolment/api_data_aadhar_enrolment_1000000_1006029.csv')

# %%
df1=pd.concat([dfi,dfii,dfiii])

# %%
df1.head()
# Out:
#          date          state          district  pincode  age_0_5  age_5_17  \
# 0  02-03-2025      Meghalaya  East Khasi Hills   793121       11        61
# 1  09-03-2025      Karnataka   Bengaluru Urban   560043       14        33
# 2  09-03-2025  Uttar Pradesh      Kanpur Nagar   208001       29        82
# 3  09-03-2025  Uttar Pradesh           Aligarh   202133       62        29
# 4  09-03-2025      Karnataka   Bengaluru Urban   560016       14        16
#
#    age_18_greater
# 0              37
# 1              39
# 2              12
# 3              15
# 4              21

# %%
df1.shape
# Out:
# (1006029, 7)

# %%
dfj=pd.read_csv('c:/Users/Tarun/Desktop/Hackathon Data/api_data_aadhar_demographic/api_data_aadhar_demographic_0_500000.csv')
dfjj=pd.read_csv('c:/Users/Tarun/Desktop/Hackathon Data/api_data_aadhar_demographic/api_data_aadhar_demographic_500000_1000000.csv')
dfjjj=pd.read_csv('c:/Users/Tarun/Desktop/Hackathon Data/api_data_aadhar_demographic/api_data_aadhar_demographic_1000000_1500000.csv')
dfjv=pd.read_csv('c:/Users/Tarun/Desktop/Hackathon Data/api_data_aadhar_demographic/api_data_aadhar_demographic_1500000_2000000.csv')
dfv=pd.read_csv('c:/Users/Tarun/Desktop/Hackathon Data/api_data_aadhar_demographic/api_data_aadhar_demographic_2000000_2071700.csv')

# %%
df2=pd.concat([dfj,dfjj,dfjjj,dfjv,dfv])

# %%
df2.head()
# Out:
#          date           state    district  pincode  demo_age_5_17  \
# 0  01-03-2025   Uttar Pradesh   Gorakhpur   273213             49
# 1  01-03-2025  Andhra Pradesh    Chittoor   517132             22
# 2  01-03-2025         Gujarat      Rajkot   360006             65
# 3  01-03-2025  Andhra Pradesh  Srikakulam   532484             24
# 4  01-03-2025       Rajasthan     Udaipur   313801             45
#
#    demo_age_17_
# 0           529
# 1           375
# 2           765
# 3           314
# 4           785

# %%
df2.shape
# Out:
# (2071700, 6)

# %%
dfk=pd.read_csv('c:/Users/Tarun/Desktop/Hackathon Data/api_data_aadhar_biometric/api_data_aadhar_biometric_0_500000.csv')
dfkk=pd.read_csv('c:/Users/Tarun/Desktop/Hackathon Data/api_data_aadhar_biometric/api_data_aadhar_biometric_500000_1000000.csv')
dfkkk=pd.read_csv('c:/Users/Tarun/Desktop/Hackathon Data/api_data_aadhar_biometric/api_data_aadhar_biometric_1000000_1500000.csv')
dfkv=pd.read_csv('c:/Users/Tarun/Desktop/Hackathon Data/api_data_aadhar_biometric/api_data_aadhar_biometric_1500000_1861108.csv')

# %%
df3=pd.concat([dfk,dfkk,dfkkk,dfkv])

# %%
df3.head()
# Out:
#          date              state      district  pincode  bio_age_5_17  \
# 0  01-03-2025            Haryana  Mahendragarh   123029           280
# 1  01-03-2025              Bihar     Madhepura   852121           144
# 2  01-03-2025  Jammu and Kashmir         Punch   185101           643
# 3  01-03-2025              Bihar       Bhojpur   802158           256
# 4  01-03-2025         Tamil Nadu       Madurai   625514           271
#
#    bio_age_17_
# 0          577
# 1          369
# 2         1091
# 3          980
# 4          815

# %%
df3.shape
# Out:
# (1861108, 6)

# %%
df1.to_csv('aadhar_enrolment_data.csv',index=False)

# %%
df2.to_csv('aadhar_demographic_data.csv',index=False)

# %%
df3.to_csv('aadhar_biometric_data.csv',index=False)
